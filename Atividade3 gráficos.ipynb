# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn

# %%
base = pd.read_csv(r'C:\Users\thiag\Desktop\Programação\Data Science\Curso DS\MaterialAula\13.Prática em Python\dados\dados.csv', sep=';')
print(base.shape)
base.head()
# Out:
# (187, 4)
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
base.isnull().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
srn.distplot(base.PIB, bins = 10, axlabel = 'PIB').set_title('PIB')
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_1316\3446410660.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base.PIB, bins = 10, axlabel = 'PIB').set_title('PIB')
# Text(0.5, 1.0, 'PIB')

# %%
srn.distplot(base.VALOREMPENHO, bins = 10, axlabel = 'Valor do Empenho').set_title('Empenho')
# Out:
# C:\Users\thiag\AppData\Local\Temp\ipykernel_1316\2828245906.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base.VALOREMPENHO, bins = 10, axlabel = 'Valor do Empenho').set_title('Empenho')
# Text(0.5, 1.0, 'Empenho')

# %%
agrupado = base.sort_values('PIB').head(5)
agrupado = agrupado.iloc[:,1:3]
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='PIB', color = 'gray')
# Out:
# <AxesSubplot: xlabel='MUNICIPIO'>

# %%
agrupado = base.sort_values('VALOREMPENHO').head(5)
agrupado = agrupado.iloc[:,[1,3]]
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'gray')
# Out:
# <AxesSubplot: xlabel='MUNICIPIO'>
